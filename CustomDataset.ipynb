# %% [markdown]
# create folder train_data
# create 2 sub folders
# 1. images
#     1.1 train
#     1.2 val
# 2. labels
#     2.1 train
#     2.2 val
#
# go to makesense.ai
# upload train images and label them and extract output in labels folder
# do the same for val
#
# export annotations as yolo
#
# open yolov5 in collab
# https://colab.research.google.com/github/ultralytics/yolov5/blob/master/tutorial.ipynb#scrollTo=4JnkELT0cIJg
#
# RUN :
#
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install
#
# import torch
# import utils
# display = utils.notebook_init()  # checks
#
#
#
# add train_data.zip
# in yolov5 > data > coco128.yaml download
# edit your custom path nd rename file as customData.yaml
# and upload
#
# unzip train data and delete zip file
#
# torch.hub.download_url_to_file('https://ultralytics.com/assets/coco2017val.zip', 'tmp.zip')  # download (780M - 5000 images)
# !unzip -q ../train_data.zip -d ../  # unzip
#
# # Train YOLOv5s on customData for 500 epochs
# !python train.py --img 640 --batch 16 --epochs 200 --data customData.yaml --weights yolov5s.pt --cache
#
# increase epoch for better result
#
# go to run and in exp see preds file .jpg

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-155-g8ecc727 Python-3.9.16 torch-2.0.0+cu118 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.3/107.7 GB disk)

# %%
# !unzip -q ../train_data.zip -d ../  # unzip

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 16 --epochs 500 --data customData.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=customData.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=500, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# requirements: /content/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-155-g8ecc727 Python-3.9.16 torch-2.0.0+cu118 CPU
#
# ...

# %%
# !python detect.py --weights runs/train/exp2/weights/best.pt --img 640 --conf 0.25 --source ../video.mp4 
#add your above wts in place of yolov5s.pt and change --source ../video.mp4 or --source 0 >> for webcam
#change confidence (conf) score to higher for accuracy
# Out:
# detect: weights=['runs/train/exp2/weights/best.pt'], source=../video.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: /content/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-155-g8ecc727 Python-3.9.16 torch-2.0.0+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/394) /content/video.mp4: 640x384 2 healthys, 295.6ms
# video 1/1 (2/394) /content/video.mp4: 640x384 2 healthys, 296.7ms
# video 1/1 (3/394) /content/video.mp4: 640x384 2 healthys, 286.0ms
# video 1/1 (4/394) /content/video.mp4: 640x384 2 healthys, 270.9ms
# ...
